# %%
import pandas as pd

# %%
df = pd.read_csv("kidney_dataset.csv")

# %%
df.head()
# Out:
#      bp     sg   al   su  rbc  pc  pcc  ba    bgr   sc  hemo  pcv  wc  rc  \
# 0  80.0  1.020  1.0  0.0    1   1    0   0  121.0  1.2  15.4   32  72  34
# 1  50.0  1.020  4.0  0.0    1   1    0   0  121.0  0.8  11.3   26  56  34
# 2  80.0  1.010  2.0  3.0    1   1    0   0  423.0  1.8   9.6   19  70  34
# 3  70.0  1.005  4.0  0.0    1   0    1   0  117.0  3.8  11.2   20  62  19
# 4  80.0  1.010  2.0  0.0    1   1    0   0  106.0  1.4  11.6   23  68  27
#
#    htn  dm  classification
# 0    1   4               0
# 1    0   3               0
# 2    0   4               0
# 3    1   3               0
# 4    0   3               0

# %%
df_reset = df.reset_index(drop=True)

# %%
df.to_csv("kidney_test1.csv", index=False)

# %%
aa = pd.read_csv("kidney_test1.csv")
